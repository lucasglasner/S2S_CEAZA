# %%
import xarray as xr
import pandas as pd
import numpy as np
from glob import glob
from dask.distributed import Client, LocalCluster
cluster = LocalCluster(n_workers=15, threads_per_worker=1)
client  = Client(cluster, asynchronous=True)
client
# Out:
# <Client: 'tcp://127.0.0.1:36373' processes=15 threads=15, memory=125.57 GiB>

# %%
masks = xr.open_dataset('data/REFORECASTS_MASKS.nc')
lon,lat = np.meshgrid(masks.lon,masks.lat)
tropicalcoords   = pd.DataFrame((lon[0,:],np.zeros(len(lon[0,:]))), index=['lon','lat']).T
lonn = []
lons = []
for i in range(len(masks.lat)):
    try:
        x = masks.coastmask_north.where(masks.coastmask_north==1).isel(lat=i).dropna('lon')[-1].lon.item()
        lonn.append(x)
    except:
        lonn.append(np.nan)
        pass
    
    try:
        x = masks.coastmask_south.where(masks.coastmask_south==1).isel(lat=i).dropna('lon')[-1].lon.item()
        lons.append(x)
    except:
        lons.append(np.nan)
        pass
coastnorthcoords = pd.DataFrame((np.array(lonn),lat[:,0]),index=['lon','lat']).T.dropna()
coastsouthcoords = pd.DataFrame((np.array(lons),lat[:,0]),index=['lon','lat']).T.dropna()

coastnorthcoords.index = coastnorthcoords.lat
coastsouthcoords.index = coastsouthcoords.lat

# %%
dirpaths = sorted(glob('data/S2S/reforecasts/*'))[:-40]
hovmoller_tropical   = []
hovmoller_coastnorth = []
hovmoller_coastsouth = []
for directory in dirpaths:
    print(directory)
    paths = glob(directory+'/*_SSH.nc')
    data1  = []
    for p in paths:
        d = xr.open_dataset(p).squeeze()
        d = d.sortby('lat').sortby('lon').sel({'lon':slice(220,290),'lat':slice(-40,40)})
        d = d.rename({'time':'leadtime'})
        d.coords['inittime'] = d.leadtime[0].values
        d['leadtime'] = np.arange(len(d.leadtime))
        data1.append(d['dslm'])
    data1     = xr.concat(data1, 'inittime').drop('depth').sortby('inittime').sortby('leadtime')
    
    paths = glob(directory+'/*_300T.nc')
    data2  = []
    for p in paths:
        d = xr.open_dataset(p).squeeze()
        d = d.sortby('lat').sortby('lon').sel({'lon':slice(220,290),'lat':slice(-40,40)})
        d = d.rename({'time':'leadtime'})
        d.coords['inittime'] = d.leadtime[0].values
        d['leadtime'] = np.arange(len(d.leadtime))
        data2.append(d['param18.4.10'])
    data2     = xr.concat(data2, 'inittime').drop('depth').sortby('inittime').sortby('leadtime')
    data = xr.merge([data1,data2.ffill('lon')])
    
    tropical = data.where(masks.tropicalmask).mean('lat').dropna('lon').sortby('lon')
    tropical.coords['index'] = ('lon',np.arange(len(tropical.lon)))
    # tropical = tropical.to_dataset(name=var[1]+'_tropical')
    
    coast_north = data.where(masks.coastmask_north).mean('lon').dropna('lat').sortby('lat')
    coast_north.coords['index'] = ('lat', 1+tropical.index[-1].item()+np.arange(len(coast_north.lat)))
    # coast_north = coast_north.to_dataset(name=var[1]+'_coastnorth')
    
    coast_south = data.where(masks.coastmask_south).mean('lon').dropna('lat').sortby('lat', ascending=False)
    coast_south.coords['index'] = ('lat', 1+tropical.index[-1].item()+np.arange(len(coast_south.lat)))
    # coast_south = coast_south.to_dataset(name=var[1]+'_coastsouth')
    
    hovmoller_tropical.append(tropical.rename({'dslm':'zos', 'param18.4.10':'T300'}))
    hovmoller_coastnorth.append(coast_north.rename({'dslm':'zos', 'param18.4.10':'T300'}))
    hovmoller_coastsouth.append(coast_south.rename({'dslm':'zos', 'param18.4.10':'T300'}))
    
print('joining')
hovmoller_tropical   = xr.concat(hovmoller_tropical, 'inittime').sortby('inittime')
hovmoller_coastnorth = xr.concat(hovmoller_coastnorth, 'inittime').sortby('inittime')
hovmoller_coastsouth = xr.concat(hovmoller_coastsouth, 'inittime').sortby('inittime')
# Out:
# data/S2S/reforecasts/2020-01-06
# data/S2S/reforecasts/2020-01-09
# data/S2S/reforecasts/2020-01-13
# data/S2S/reforecasts/2020-01-16
# data/S2S/reforecasts/2020-01-20
# data/S2S/reforecasts/2020-01-23
# data/S2S/reforecasts/2020-01-27
# data/S2S/reforecasts/2020-01-30
# data/S2S/reforecasts/2020-02-03
# data/S2S/reforecasts/2020-02-06
# data/S2S/reforecasts/2020-02-10
# data/S2S/reforecasts/2020-02-13
# data/S2S/reforecasts/2020-02-17
# data/S2S/reforecasts/2020-02-20
# data/S2S/reforecasts/2020-02-24
# data/S2S/reforecasts/2020-02-27
# data/S2S/reforecasts/2020-03-02
# data/S2S/reforecasts/2020-03-05
# data/S2S/reforecasts/2020-03-09
# data/S2S/reforecasts/2020-03-12
# data/S2S/reforecasts/2020-03-16
# data/S2S/reforecasts/2020-03-19
# data/S2S/reforecasts/2020-03-23
# data/S2S/reforecasts/2020-03-26
# data/S2S/reforecasts/2020-03-30
# data/S2S/reforecasts/2020-04-02
# data/S2S/reforecasts/2020-04-06
# data/S2S/reforecasts/2020-04-09
# data/S2S/reforecasts/2020-04-13
# data/S2S/reforecasts/2020-04-16
# data/S2S/reforecasts/2020-04-20
# data/S2S/reforecasts/2020-04-23
# data/S2S/reforecasts/2020-04-27
# data/S2S/reforecasts/2020-04-30
# data/S2S/reforecasts/2020-05-04
# data/S2S/reforecasts/2020-05-07
# data/S2S/reforecasts/2020-05-11
# data/S2S/reforecasts/2020-05-14
# data/S2S/reforecasts/2020-05-18
# data/S2S/reforecasts/2020-05-21
# data/S2S/reforecasts/2020-05-25
# data/S2S/reforecasts/2020-05-28
# data/S2S/reforecasts/2020-06-01
# data/S2S/reforecasts/2020-06-04
# data/S2S/reforecasts/2020-06-08
# data/S2S/reforecasts/2020-06-11
# data/S2S/reforecasts/2020-06-15
# data/S2S/reforecasts/2020-06-18
# data/S2S/reforecasts/2020-06-22
# data/S2S/reforecasts/2020-06-25
# data/S2S/reforecasts/2020-06-29
# data/S2S/reforecasts/2020-07-02
# data/S2S/reforecasts/2020-07-06
# data/S2S/reforecasts/2020-07-09
# data/S2S/reforecasts/2020-07-13
# data/S2S/reforecasts/2020-07-16
# data/S2S/reforecasts/2020-07-20
# data/S2S/reforecasts/2020-07-23
# data/S2S/reforecasts/2020-07-27
# data/S2S/reforecasts/2020-07-30
# data/S2S/reforecasts/2020-08-03
# data/S2S/reforecasts/2020-08-06
# data/S2S/reforecasts/2020-08-10
# data/S2S/reforecasts/2020-08-13
# data/S2S/reforecasts/2020-08-17
# data/S2S/reforecasts/2020-08-20
# data/S2S/reforecasts/2020-08-24
# data/S2S/reforecasts/2020-08-27
# data/S2S/reforecasts/2020-08-31
# data/S2S/reforecasts/2020-09-03
# data/S2S/reforecasts/2020-09-07
# data/S2S/reforecasts/2020-09-10
# data/S2S/reforecasts/2020-09-14
# data/S2S/reforecasts/2020-09-17
# data/S2S/reforecasts/2020-09-21
# data/S2S/reforecasts/2020-09-24
# data/S2S/reforecasts/2020-09-28
# data/S2S/reforecasts/2020-10-01
# data/S2S/reforecasts/2020-10-05
# data/S2S/reforecasts/2020-10-08
# data/S2S/reforecasts/2020-10-12
# data/S2S/reforecasts/2020-10-15
# data/S2S/reforecasts/2020-10-19
# data/S2S/reforecasts/2020-10-22
# data/S2S/reforecasts/2020-10-26
# data/S2S/reforecasts/2020-10-29
# data/S2S/reforecasts/2020-11-02
# data/S2S/reforecasts/2020-11-05
# data/S2S/reforecasts/2020-11-09
# data/S2S/reforecasts/2020-11-12
# data/S2S/reforecasts/2020-11-16
# data/S2S/reforecasts/2020-11-19
# data/S2S/reforecasts/2020-11-23
# data/S2S/reforecasts/2020-11-26
# data/S2S/reforecasts/2020-11-30
# data/S2S/reforecasts/2020-12-03
# data/S2S/reforecasts/2020-12-07
# data/S2S/reforecasts/2020-12-10
# data/S2S/reforecasts/2020-12-14
# data/S2S/reforecasts/2020-12-17
# data/S2S/reforecasts/2020-12-21
# data/S2S/reforecasts/2020-12-24
# data/S2S/reforecasts/2020-12-28
# data/S2S/reforecasts/2020-12-31
# data/S2S/reforecasts/2021-01-04
# data/S2S/reforecasts/2021-01-07
# data/S2S/reforecasts/2021-01-11
# data/S2S/reforecasts/2021-01-14
# data/S2S/reforecasts/2021-01-18
# data/S2S/reforecasts/2021-01-21
# data/S2S/reforecasts/2021-01-25
# data/S2S/reforecasts/2021-01-28
# data/S2S/reforecasts/2021-02-01
# data/S2S/reforecasts/2021-02-04
# data/S2S/reforecasts/2021-02-08
# data/S2S/reforecasts/2021-02-11
# data/S2S/reforecasts/2021-02-15
# data/S2S/reforecasts/2021-02-18
# data/S2S/reforecasts/2021-02-22
# data/S2S/reforecasts/2021-02-25
# data/S2S/reforecasts/2021-03-01
# data/S2S/reforecasts/2021-03-04
# data/S2S/reforecasts/2021-03-08
# data/S2S/reforecasts/2021-03-11
# data/S2S/reforecasts/2021-03-15
# data/S2S/reforecasts/2021-03-18
# data/S2S/reforecasts/2021-03-22
# data/S2S/reforecasts/2021-03-25
# data/S2S/reforecasts/2021-03-29
# data/S2S/reforecasts/2021-04-01
# data/S2S/reforecasts/2021-04-05
# data/S2S/reforecasts/2021-04-08
# data/S2S/reforecasts/2021-04-12
# data/S2S/reforecasts/2021-04-15
# data/S2S/reforecasts/2021-04-19
# data/S2S/reforecasts/2021-04-22
# data/S2S/reforecasts/2021-04-26
# data/S2S/reforecasts/2021-04-29
# data/S2S/reforecasts/2021-05-03
# data/S2S/reforecasts/2021-05-06
# data/S2S/reforecasts/2021-05-10
# data/S2S/reforecasts/2021-05-13
# data/S2S/reforecasts/2021-05-17
# data/S2S/reforecasts/2021-05-20
# data/S2S/reforecasts/2021-05-24
# data/S2S/reforecasts/2021-05-27
# data/S2S/reforecasts/2021-05-31
# data/S2S/reforecasts/2021-06-03
# data/S2S/reforecasts/2021-06-07
# data/S2S/reforecasts/2021-06-10
# data/S2S/reforecasts/2021-06-14
# data/S2S/reforecasts/2021-06-17
# data/S2S/reforecasts/2021-06-21
# data/S2S/reforecasts/2021-06-24
# data/S2S/reforecasts/2021-06-28
# data/S2S/reforecasts/2021-07-01
# data/S2S/reforecasts/2021-07-05
# data/S2S/reforecasts/2021-07-08
# data/S2S/reforecasts/2021-07-12
# data/S2S/reforecasts/2021-07-15
# data/S2S/reforecasts/2021-07-19
# data/S2S/reforecasts/2021-07-22
# data/S2S/reforecasts/2021-07-26
# data/S2S/reforecasts/2021-07-29
# data/S2S/reforecasts/2021-08-02
# data/S2S/reforecasts/2021-08-05
# data/S2S/reforecasts/2021-08-09
# data/S2S/reforecasts/2021-08-12
# data/S2S/reforecasts/2021-08-16
# data/S2S/reforecasts/2021-08-19
# data/S2S/reforecasts/2021-08-23
# data/S2S/reforecasts/2021-08-26
# data/S2S/reforecasts/2021-08-30
# data/S2S/reforecasts/2021-09-02
# data/S2S/reforecasts/2021-09-06
# data/S2S/reforecasts/2021-09-09
# data/S2S/reforecasts/2021-09-13
# data/S2S/reforecasts/2021-09-16
# data/S2S/reforecasts/2021-09-20
# data/S2S/reforecasts/2021-09-23
# data/S2S/reforecasts/2021-09-27
# data/S2S/reforecasts/2021-09-30
# data/S2S/reforecasts/2021-10-04
# data/S2S/reforecasts/2021-10-07
# data/S2S/reforecasts/2021-10-11
# data/S2S/reforecasts/2021-10-14
# data/S2S/reforecasts/2021-10-18
# data/S2S/reforecasts/2021-10-21
# data/S2S/reforecasts/2021-10-25
# data/S2S/reforecasts/2021-10-28
# data/S2S/reforecasts/2021-11-01
# data/S2S/reforecasts/2021-11-04
# data/S2S/reforecasts/2021-11-08
# data/S2S/reforecasts/2021-11-11
# data/S2S/reforecasts/2021-11-15
# data/S2S/reforecasts/2021-11-18
# data/S2S/reforecasts/2021-11-22
# data/S2S/reforecasts/2021-11-25
# data/S2S/reforecasts/2021-11-29
# data/S2S/reforecasts/2021-12-02
# data/S2S/reforecasts/2021-12-06
# data/S2S/reforecasts/2021-12-09
# data/S2S/reforecasts/2021-12-13
# data/S2S/reforecasts/2021-12-16
# data/S2S/reforecasts/2021-12-20
# data/S2S/reforecasts/2021-12-23
# data/S2S/reforecasts/2021-12-27
# data/S2S/reforecasts/2021-12-30
# data/S2S/reforecasts/2022-01-03
# data/S2S/reforecasts/2022-01-06
# data/S2S/reforecasts/2022-01-10
# data/S2S/reforecasts/2022-01-13
# data/S2S/reforecasts/2022-01-17
# data/S2S/reforecasts/2022-01-20
# data/S2S/reforecasts/2022-01-24
# data/S2S/reforecasts/2022-01-27
# data/S2S/reforecasts/2022-01-31
# data/S2S/reforecasts/2022-02-03
# data/S2S/reforecasts/2022-02-07
# data/S2S/reforecasts/2022-02-10
# data/S2S/reforecasts/2022-02-14
# data/S2S/reforecasts/2022-02-17
# data/S2S/reforecasts/2022-02-21
# data/S2S/reforecasts/2022-02-24
# data/S2S/reforecasts/2022-02-28
# data/S2S/reforecasts/2022-03-03
# data/S2S/reforecasts/2022-03-07
# data/S2S/reforecasts/2022-03-10
# data/S2S/reforecasts/2022-03-14
# data/S2S/reforecasts/2022-03-17
# data/S2S/reforecasts/2022-03-21
# data/S2S/reforecasts/2022-03-24
# data/S2S/reforecasts/2022-03-28
# data/S2S/reforecasts/2022-03-31
# data/S2S/reforecasts/2022-04-04
# data/S2S/reforecasts/2022-04-07
# data/S2S/reforecasts/2022-04-11
# data/S2S/reforecasts/2022-04-14
# data/S2S/reforecasts/2022-04-18
# data/S2S/reforecasts/2022-04-21
# data/S2S/reforecasts/2022-04-25
# data/S2S/reforecasts/2022-04-28
# data/S2S/reforecasts/2022-05-02
# data/S2S/reforecasts/2022-05-05
# data/S2S/reforecasts/2022-05-09
# data/S2S/reforecasts/2022-05-12
# data/S2S/reforecasts/2022-05-16
# data/S2S/reforecasts/2022-05-19
# data/S2S/reforecasts/2022-05-23
# data/S2S/reforecasts/2022-05-26
# data/S2S/reforecasts/2022-05-30
# data/S2S/reforecasts/2022-06-02
# data/S2S/reforecasts/2022-06-06
# data/S2S/reforecasts/2022-06-09
# data/S2S/reforecasts/2022-06-13
# data/S2S/reforecasts/2022-06-16
# data/S2S/reforecasts/2022-06-20
# data/S2S/reforecasts/2022-06-23
# data/S2S/reforecasts/2022-06-27
# data/S2S/reforecasts/2022-06-30
# data/S2S/reforecasts/2022-07-04
# data/S2S/reforecasts/2022-07-07
# data/S2S/reforecasts/2022-07-11
# data/S2S/reforecasts/2022-07-14
# data/S2S/reforecasts/2022-07-18
# data/S2S/reforecasts/2022-07-21
# data/S2S/reforecasts/2022-07-25
# data/S2S/reforecasts/2022-07-28
# data/S2S/reforecasts/2022-08-01
# data/S2S/reforecasts/2022-08-04
# data/S2S/reforecasts/2022-08-08
# data/S2S/reforecasts/2022-08-11
# data/S2S/reforecasts/2022-08-15
# data/S2S/reforecasts/2022-08-18
# data/S2S/reforecasts/2022-08-22
# data/S2S/reforecasts/2022-08-25
# data/S2S/reforecasts/2022-08-29
# data/S2S/reforecasts/2022-09-01
# data/S2S/reforecasts/2022-09-05
# data/S2S/reforecasts/2022-09-08
# data/S2S/reforecasts/2022-09-12
# data/S2S/reforecasts/2022-09-15
# data/S2S/reforecasts/2022-09-19
# data/S2S/reforecasts/2022-09-22
# data/S2S/reforecasts/2022-09-26
# data/S2S/reforecasts/2022-09-29
# data/S2S/reforecasts/2022-10-03
# data/S2S/reforecasts/2022-10-06
# data/S2S/reforecasts/2022-10-10
# data/S2S/reforecasts/2022-10-13
# data/S2S/reforecasts/2022-10-17
# data/S2S/reforecasts/2022-10-20
# data/S2S/reforecasts/2022-10-24
# data/S2S/reforecasts/2022-10-27
# data/S2S/reforecasts/2022-10-31
# data/S2S/reforecasts/2022-11-03
# data/S2S/reforecasts/2022-11-07
# data/S2S/reforecasts/2022-11-10
# data/S2S/reforecasts/2022-11-14
# data/S2S/reforecasts/2022-11-17
# data/S2S/reforecasts/2022-11-21
# data/S2S/reforecasts/2022-11-24
# data/S2S/reforecasts/2022-11-28
# data/S2S/reforecasts/2022-12-01
# data/S2S/reforecasts/2022-12-05
# data/S2S/reforecasts/2022-12-08
# data/S2S/reforecasts/2022-12-12
# data/S2S/reforecasts/2022-12-15
# joining

# %%
hovmoller_tropical   = hovmoller_tropical.swap_dims({'lon':'index'})
hovmoller_coastnorth = hovmoller_coastnorth.swap_dims({'lat':'index'})
hovmoller_coastsouth = hovmoller_coastsouth.swap_dims({'lat':'index'})

# %%
hovmoller_tropical.coords['lat']    = ('index', np.zeros(len(tropical.lon)))
hovmoller_coastnorth.coords['lon']  = ('index', coastnorthcoords.loc[hovmoller_coastnorth.lat.values].lon.values)
hovmoller_coastsouth.coords['lon']  = ('index', coastsouthcoords.loc[hovmoller_coastsouth.lat.values].lon.values)

# %%
def haversine(p1,p2):
    """
    Given two points with lat,lon coordinates, compute the distance
    between those points on the surface of the sphere with the haversine formula
    Args:
        p1 (tuple): first point lat,lon
        p2 (tuple): last point lat,lon

    Returns:
        float: distance
    """
    lat1,lon1 = p1
    lat2,lon2 = p2

    lon1,lon2,lat1,lat2 = map(np.deg2rad, [lon1,lon2,lat1,lat2])

    dlon = lon2-lon1
    dlat = lat2-lat1

    a = np.sin(dlat/2)**2+np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    c = 2*np.arcsin(np.sqrt(a))
    r = 6371
    return c*r

def distances(data):
    distance = []
    for i in range(len(data.lon.values)-1):
        lon1,lat1 = data.lon.values[i], data.lat.values[i]
        lon2,lat2 = data.lon.values[i+1], data.lat.values[i+1]
        dist = haversine(p1=(lat2,lon2), p2=(lat1,lon1))
        distance.append(dist)
    distance = np.hstack([np.array([0]),np.array(distance)])
    distance = np.cumsum(distance)
    return distance

# %%
tropicaldistance   = distances(hovmoller_tropical)
coastnorthdistance = distances(hovmoller_coastnorth) + tropicaldistance[-1]+1
coastsouthdistance = distances(hovmoller_coastsouth) + tropicaldistance[-1]+1
hovmoller_tropical.coords['distance']    = ('index', tropicaldistance)
hovmoller_coastnorth.coords['distance']  = ('index', coastnorthdistance)
hovmoller_coastsouth.coords['distance']  = ('index', coastsouthdistance)

# %%
hovmoller_tropical.to_netcdf('data/S2S/HOVMOLLERS/reforecasts_tropical.nc')
hovmoller_coastnorth.to_netcdf('data/S2S/HOVMOLLERS/reforecasts_coastnorth.nc')
hovmoller_coastsouth.to_netcdf('data/S2S/HOVMOLLERS/reforecasts_coastsouth.nc')

# %%
client.shutdown()
# Out:
# 2023-05-08 12:09:53,125 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
